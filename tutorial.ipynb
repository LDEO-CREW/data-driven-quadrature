# %% [markdown]
# # Data Driven Quadrature Tutorial
#
# ### by Neal Ma
#
# Welcome! This python notebook shows an example of how to use the data driven quadrature package. Here we generate synthetic data, define appropriate cost and mapping functions, and show the results of this toy-box optimization problem.

# %%
# import libraries
import numpy as np
import xarray as xr
import cvxpy as cp
import datadrivenquadrature as ddq

# not required but for visualization
import matplotlib.pyplot as plt

# %% [markdown]
# #### Define functions for data generation
#
# In this example, we use a piece-wise function in our data. The function is defined as:
#
# $$f(x) = \left\{
# \begin{array}{ll}
#     \frac{idx_{x}}{16}(x)(x - 8) \\
#     \frac{idx_{y}}{4}(x-8)(x-12)
# \end{array}
# \right. $$
#
# where $idx_x$ and $idx_y$ are parameters we use to vary the defined spectra across the our dataframe. These are two downward facing parabolas centered at $x=4$ and $x=10$ with roots at $x=0, 8, 12$. We use a range $0 \leq x \leq 12$ which allows us to find a closed form solution for the integral as:
#
# $$\begin{align*}
#     V = \int_{0}^{12} f(x) = \frac{16}{3} idx_x + \frac{8}{3} idx_y
# \end{align*}$$

# %%
def user_function(x, x_idx, y_idx):
    # comment out below this line if you would like to test your own function
    val = 0
    if x < 8:
        val = (-x_idx / 16.) * (x) * (x - 8)
    else:
        val = (-y_idx / 4.) * (x - 8) * (x - 12)
    return val

def generate_spectra(x_idx, y_idx, x_min, x_max, s=1000):
    spectra = []
    x = np.arange(x_min, x_max, 1./s)
    for val in x:
        spectra.append(user_function(val, x_idx, y_idx))
    return spectra

def compute_exact_integral(x, x_idx, y_idx, s):
    # exact closed-form solution of example function above
    return 16./3 * x_idx + 8./3 * y_idx
    # comment above and uncomment below if using your own non-closed form function
    # return sum(x) / s

# %% [markdown]
# We can visualize this spectra for $idx_x = 2, idx_y = 4$:

# %%
graph_spectra = generate_spectra(2, 4, 0, 12, s=1000)
x = np.arange(0, 12, 1/1000.)
plt.plot(x, graph_spectra)

# %% [markdown]
# #### Build dataset for optimization
#
# Here, we generate data to use for the optimization. We define a 10 by 10 grid of spectra where the x index ($idx_x$) and y index ($idx_y$) of the spectra within the dataset are used as parameters for parabola heights (see function definition above).

# %%
n = 10 # size of square block of data
s = 1000 # reciprocal step size of the integration axis

# initialize empty arrays to hold synthetic data
x_integrated = []
x_spectra = []

# generate and store synthetic data
for y_idx in range(n):
    x_integrated_row = []
    x_spectra_row = []
    for x_idx in range(n):
        x_spectra_row.append(generate_spectra(x_idx + 1, y_idx + 1, 0, 12, s))
        x_integrated_row.append(compute_exact_integral(x_spectra_row[-1], x_idx + 1, y_idx + 1, s))
    x_integrated.append(x_integrated_row)
    x_spectra.append(x_spectra_row)

# generate integration axis 
x_range = np.arange(0, 12, 1./s)

# store synthetic data in a xarray data array
x = xr.DataArray(x_spectra,
    dims=("x_idx", "y_idx", "integration_axis"), 
    coords={"x_idx": list(np.arange(1, n + 1, 1)),
             "y_idx": list(np.arange(1, n + 1, 1)),
             "integration_axis": x_range}
)

# store pre-calculated integrals; not necessary but can just for good record keeping
y = xr.DataArray(x_integrated,
    dims=("x_idx", "y_idx"), 
    coords={"x_idx": list(np.arange(1, n + 1, 1)),
             "y_idx": list(np.arange(1, n + 1, 1))}
)

# extract the reference values in a flattened array
y_ref = y.values.flatten()

# %%
# number of integration points to use
n_integration_points = 12

# user defined cost function using only built-in cvxpy functions
def user_cost_fnc(y, y_hat):
    cost = cp.norm(y - y_hat)
    return cost

# user defined mapping function that returns 
def map_func(x, point_set, x_sup=None):
    # extract point indices from the point set
    point_idxs = [point[0] for point in point_set]
    # extract point vector and return in matrix of shape (# spectra, # integration points)
    points = np.array(x[:,:,point_idxs].values).reshape((n*n, n_integration_points))
    return points

# define parameters for optimization
params = {}
integration_list = ['integration_axis']
params['integration_list'] = integration_list # REQUIRED
params['n_points'] = n_integration_points # REQUIRED
params['epochs'] = 250 # OPTIONAL
params['success'] = 50 # OPTIONAL
params['block_size'] = 100 # OPTIONAL
params['random_seed'] = 1 # OPTIONAL
params['verbose'] = 2 # OPTIONAL

# run the optimization and safe the history dictionary
# NOTE: y_ref must be normalized to an integration axis of length 1, so we divide y_ref by 12 (length of integration axis)
history = ddq.optimize(x, y_ref / 12, user_cost_fnc, map_func, params, x_sup=None)
# Out:
# EPOCH: 1	AVG COST: 6.748e-02	BEST COST: 9.003e-12
# EPOCH: 2	AVG COST: 2.296e-02	BEST COST: 9.003e-12
# EPOCH: 3	AVG COST: 1.090e-10	BEST COST: 7.892e-13
# EPOCH: 4	AVG COST: 1.258e-01	BEST COST: 7.892e-13
# EPOCH: 5	AVG COST: 1.236e-10	BEST COST: 7.892e-13
# EPOCH: 6	AVG COST: 1.040e-10	BEST COST: 6.911e-13
# EPOCH: 7	AVG COST: 2.057e-10	BEST COST: 6.911e-13
# EPOCH: 8	AVG COST: 1.672e-01	BEST COST: 6.911e-13
# EPOCH: 9	AVG COST: 8.540e-11	BEST COST: 6.911e-13
# EPOCH: 10	AVG COST: 1.236e-10	BEST COST: 6.911e-13
# EPOCH: 11	AVG COST: 9.340e-02	BEST COST: 6.911e-13
# EPOCH: 12	AVG COST: 1.010e-10	BEST COST: 6.911e-13
# EPOCH: 13	AVG COST: 8.636e-11	BEST COST: 6.911e-13
# EPOCH: 14	AVG COST: 1.009e-10	BEST COST: 6.911e-13
# EPOCH: 15	AVG COST: 8.336e-02	BEST COST: 6.911e-13
# EPOCH: 16	AVG COST: 9.149e-11	BEST COST: 6.911e-13
# EPOCH: 17	AVG COST: 7.152e-01	BEST COST: 6.911e-13
# EPOCH: 18	AVG COST: 1.567e-10	BEST COST: 6.911e-13
# EPOCH: 19	AVG COST: 1.391e-10	BEST COST: 6.911e-13
# EPOCH: 20	AVG COST: 1.568e-10	BEST COST: 6.911e-13
# EPOCH: 21	AVG COST: 1.299e-10	BEST COST: 6.911e-13
# EPOCH: 22	AVG COST: 1.067e-10	BEST COST: 6.911e-13
# EPOCH: 23	AVG COST: 3.281e-01	BEST COST: 6.911e-13
# EPOCH: 24	AVG COST: 8.529e-11	BEST COST: 6.911e-13
# EPOCH: 25	AVG COST: 1.148e-10	BEST COST: 6.911e-13
# EPOCH: 26	AVG COST: 8.230e-11	BEST COST: 6.911e-13
# EPOCH: 27	AVG COST: 9.393e-02	BEST COST: 6.911e-13
# EPOCH: 28	AVG COST: 1.045e-10	BEST COST: 6.911e-13
# EPOCH: 29	AVG COST: 1.198e-02	BEST COST: 6.911e-13
# EPOCH: 30	AVG COST: 9.875e-11	BEST COST: 6.911e-13
# EPOCH: 31	AVG COST: 8.971e-02	BEST COST: 6.911e-13
# EPOCH: 32	AVG COST: 1.085e-10	BEST COST: 6.911e-13
# EPOCH: 33	AVG COST: 1.649e-10	BEST COST: 6.911e-13
# EPOCH: 34	AVG COST: 2.108e-01	BEST COST: 6.911e-13
# EPOCH: 35	AVG COST: 7.223e-11	BEST COST: 6.911e-13
# EPOCH: 36	AVG COST: 9.116e-11	BEST COST: 6.911e-13
# EPOCH: 37	AVG COST: 1.145e-10	BEST COST: 6.911e-13
# EPOCH: 38	AVG COST: 1.995e-01	BEST COST: 6.911e-13
# EPOCH: 39	AVG COST: 1.672e-01	BEST COST: 6.911e-13
# EPOCH: 40	AVG COST: 7.889e-02	BEST COST: 6.911e-13
# EPOCH: 41	AVG COST: 1.670e-02	BEST COST: 6.911e-13
# EPOCH: 42	AVG COST: 1.048e-10	BEST COST: 6.911e-13
# EPOCH: 43	AVG COST: 1.227e-02	BEST COST: 6.911e-13
# EPOCH: 44	AVG COST: 1.465e-10	BEST COST: 6.911e-13
# EPOCH: 45	AVG COST: 2.452e-01	BEST COST: 6.911e-13
# EPOCH: 46	AVG COST: 1.490e-10	BEST COST: 6.911e-13
# EPOCH: 47	AVG COST: 5.434e-03	BEST COST: 6.911e-13
# EPOCH: 48	AVG COST: 1.370e-10	BEST COST: 6.911e-13
# EPOCH: 49	AVG COST: 1.267e-10	BEST COST: 6.911e-13
# EPOCH: 50	AVG COST: 2.814e-02	BEST COST: 6.911e-13
# EPOCH: 51	AVG COST: 5.721e-02	BEST COST: 6.911e-13
# EPOCH: 52	AVG COST: 1.051e-10	BEST COST: 6.911e-13
# EPOCH: 53	AVG COST: 9.312e-11	BEST COST: 6.911e-13
# EPOCH: 54	AVG COST: 1.672e-01	BEST COST: 6.911e-13
# EPOCH: 55	AVG COST: 1.716e-10	BEST COST: 6.911e-13
# EPOCH: 56	AVG COST: 2.286e-02	BEST COST: 6.911e-13
# EPOCH: 57	AVG COST: 1.093e-10	BEST COST: 6.911e-13
# EPOCH: 58	AVG COST: 6.001e-02	BEST COST: 6.911e-13
# EPOCH: 59	AVG COST: 9.979e-11	BEST COST: 6.911e-13
# EPOCH: 60	AVG COST: 1.261e-01	BEST COST: 6.911e-13
# EPOCH: 61	AVG COST: 1.273e-01	BEST COST: 6.911e-13
# EPOCH: 62	AVG COST: 1.113e-10	BEST COST: 6.911e-13
# EPOCH: 63	AVG COST: 1.672e-01	BEST COST: 6.911e-13
# EPOCH: 64	AVG COST: 2.378e-01	BEST COST: 6.911e-13
# EPOCH: 65	AVG COST: 1.672e-01	BEST COST: 6.911e-13
# EPOCH: 66	AVG COST: 9.212e-02	BEST COST: 6.911e-13
# EPOCH: 67	AVG COST: 1.349e-10	BEST COST: 6.911e-13
# EPOCH: 68	AVG COST: 1.004e-10	BEST COST: 6.911e-13
# EPOCH: 69	AVG COST: 9.227e-11	BEST COST: 6.911e-13
# EPOCH: 70	AVG COST: 1.672e-01	BEST COST: 6.911e-13
# EPOCH: 71	AVG COST: 1.191e-10	BEST COST: 6.911e-13
# EPOCH: 72	AVG COST: 2.411e-01	BEST COST: 6.911e-13
# EPOCH: 73	AVG COST: 8.830e-02	BEST COST: 6.911e-13
# EPOCH: 74	AVG COST: 1.455e-01	BEST COST: 6.911e-13
# EPOCH: 75	AVG COST: 1.206e-10	BEST COST: 6.911e-13
# EPOCH: 76	AVG COST: 1.207e-10	BEST COST: 6.911e-13
# EPOCH: 77	AVG COST: 1.436e-10	BEST COST: 6.911e-13
# EPOCH: 78	AVG COST: 1.384e-10	BEST COST: 6.911e-13
# EPOCH: 79	AVG COST: 1.274e-01	BEST COST: 6.911e-13
# EPOCH: 80	AVG COST: 8.066e-11	BEST COST: 6.911e-13
# EPOCH: 81	AVG COST: 1.445e-10	BEST COST: 6.911e-13
# EPOCH: 82	AVG COST: 8.786e-11	BEST COST: 6.911e-13
# EPOCH: 83	AVG COST: 9.835e-11	BEST COST: 6.911e-13
# EPOCH: 84	AVG COST: 1.204e-10	BEST COST: 6.911e-13
# EPOCH: 85	AVG COST: 8.826e-11	BEST COST: 6.911e-13
# EPOCH: 86	AVG COST: 8.549e-02	BEST COST: 6.911e-13
# EPOCH: 87	AVG COST: 1.241e-10	BEST COST: 6.911e-13
# EPOCH: 88	AVG COST: 1.881e-10	BEST COST: 6.911e-13
# EPOCH: 89	AVG COST: 9.680e-11	BEST COST: 6.911e-13
# EPOCH: 90	AVG COST: 1.277e-10	BEST COST: 6.911e-13
# EPOCH: 91	AVG COST: 1.455e-10	BEST COST: 6.911e-13
# EPOCH: 92	AVG COST: 1.672e-01	BEST COST: 6.911e-13
# EPOCH: 93	AVG COST: 8.914e-02	BEST COST: 6.911e-13
# EPOCH: 94	AVG COST: 1.414e-10	BEST COST: 6.911e-13
# EPOCH: 95	AVG COST: 1.271e-10	BEST COST: 6.911e-13
# EPOCH: 96	AVG COST: 8.597e-01	BEST COST: 6.911e-13
# EPOCH: 97	AVG COST: 1.339e-10	BEST COST: 6.911e-13
# EPOCH: 98	AVG COST: 8.936e-11	BEST COST: 6.911e-13
# EPOCH: 99	AVG COST: 7.642e-02	BEST COST: 6.911e-13
# EPOCH: 100	AVG COST: 2.180e-01	BEST COST: 6.911e-13
# EPOCH: 101	AVG COST: 8.960e-11	BEST COST: 6.911e-13
# EPOCH: 102	AVG COST: 1.616e-10	BEST COST: 6.911e-13
# EPOCH: 103	AVG COST: 1.395e-10	BEST COST: 6.911e-13
# EPOCH: 104	AVG COST: 7.319e-11	BEST COST: 6.911e-13
# EPOCH: 105	AVG COST: 1.591e-01	BEST COST: 6.911e-13
# EPOCH: 106	AVG COST: 1.591e-01	BEST COST: 6.911e-13
# EPOCH: 107	AVG COST: 7.545e-02	BEST COST: 6.911e-13
# EPOCH: 108	AVG COST: 1.240e-10	BEST COST: 6.911e-13
# EPOCH: 109	AVG COST: 8.692e-03	BEST COST: 6.911e-13
# EPOCH: 110	AVG COST: 2.409e-10	BEST COST: 6.911e-13
# EPOCH: 111	AVG COST: 1.000e-10	BEST COST: 6.911e-13
# EPOCH: 112	AVG COST: 1.042e-10	BEST COST: 6.911e-13
# EPOCH: 113	AVG COST: 7.017e-11	BEST COST: 6.911e-13
# EPOCH: 114	AVG COST: 4.767e-02	BEST COST: 6.911e-13
# EPOCH: 115	AVG COST: 8.165e-11	BEST COST: 6.911e-13
# EPOCH: 116	AVG COST: 8.236e-02	BEST COST: 6.911e-13
# EPOCH: 117	AVG COST: 2.424e-10	BEST COST: 6.911e-13
# EPOCH: 118	AVG COST: 1.129e-10	BEST COST: 6.911e-13
# EPOCH: 119	AVG COST: 1.289e-10	BEST COST: 6.911e-13
# EPOCH: 120	AVG COST: 4.919e-03	BEST COST: 6.911e-13
# EPOCH: 121	AVG COST: 7.288e-11	BEST COST: 6.911e-13
# EPOCH: 122	AVG COST: 2.490e-02	BEST COST: 6.911e-13
# EPOCH: 123	AVG COST: 4.282e-10	BEST COST: 6.911e-13
# EPOCH: 124	AVG COST: 1.080e-10	BEST COST: 6.911e-13
# EPOCH: 125	AVG COST: 7.641e-11	BEST COST: 6.911e-13
# EPOCH: 126	AVG COST: 8.751e-11	BEST COST: 6.911e-13
# EPOCH: 127	AVG COST: 5.373e-11	BEST COST: 6.911e-13
# EPOCH: 128	AVG COST: 1.763e-01	BEST COST: 6.911e-13
# c:\Users\Astro\OneDrive\Desktop\Columbia\DSI\data-driven-quadrature\datadrivenquadrature.py:151: RuntimeWarning: overflow encountered in exp
#   return np.exp((last_cost - current_cost)/T)
# EPOCH: 129	AVG COST: 1.651e-10	BEST COST: 6.911e-13
# EPOCH: 130	AVG COST: 1.022e-10	BEST COST: 6.911e-13
# EPOCH: 131	AVG COST: 1.019e-10	BEST COST: 6.911e-13
# EPOCH: 132	AVG COST: 5.138e-02	BEST COST: 6.911e-13
# EPOCH: 133	AVG COST: 1.135e-10	BEST COST: 6.911e-13
# EPOCH: 134	AVG COST: 2.138e-10	BEST COST: 6.911e-13
# EPOCH: 135	AVG COST: 8.756e-11	BEST COST: 6.911e-13
# EPOCH: 136	AVG COST: 9.236e-11	BEST COST: 6.911e-13
# EPOCH: 137	AVG COST: 9.248e-11	BEST COST: 6.911e-13
# EPOCH: 138	AVG COST: 1.264e-01	BEST COST: 6.911e-13
# EPOCH: 139	AVG COST: 1.317e-01	BEST COST: 6.911e-13
# EPOCH: 140	AVG COST: 8.178e-11	BEST COST: 6.911e-13
# EPOCH: 141	AVG COST: 5.958e-11	BEST COST: 6.911e-13
# EPOCH: 142	AVG COST: 9.620e-11	BEST COST: 6.911e-13
# EPOCH: 143	AVG COST: 8.462e-11	BEST COST: 6.911e-13
# EPOCH: 144	AVG COST: 1.051e-10	BEST COST: 6.911e-13
# EPOCH: 145	AVG COST: 7.426e-03	BEST COST: 6.911e-13
# EPOCH: 146	AVG COST: 3.281e-01	BEST COST: 6.911e-13
# EPOCH: 147	AVG COST: 7.897e-11	BEST COST: 6.911e-13
# EPOCH: 148	AVG COST: 5.753e-03	BEST COST: 6.911e-13
# EPOCH: 149	AVG COST: 1.672e-01	BEST COST: 6.911e-13
# EPOCH: 150	AVG COST: 1.128e-10	BEST COST: 6.911e-13
# EPOCH: 151	AVG COST: 1.640e-10	BEST COST: 6.911e-13
# EPOCH: 152	AVG COST: 7.155e-11	BEST COST: 6.911e-13
# EPOCH: 153	AVG COST: 1.332e-10	BEST COST: 6.911e-13
# EPOCH: 154	AVG COST: 7.692e-11	BEST COST: 6.911e-13
# EPOCH: 155	AVG COST: 1.134e-10	BEST COST: 6.911e-13
# EPOCH: 156	AVG COST: 1.527e-10	BEST COST: 6.911e-13
# EPOCH: 157	AVG COST: 1.709e-02	BEST COST: 6.911e-13
# EPOCH: 158	AVG COST: 7.213e-11	BEST COST: 6.911e-13
# EPOCH: 159	AVG COST: 6.218e-11	BEST COST: 6.911e-13
# EPOCH: 160	AVG COST: 8.054e-11	BEST COST: 6.911e-13
# EPOCH: 161	AVG COST: 2.668e-10	BEST COST: 6.911e-13
# EPOCH: 162	AVG COST: 1.241e-01	BEST COST: 6.911e-13
# EPOCH: 163	AVG COST: 1.241e-10	BEST COST: 6.911e-13
# EPOCH: 164	AVG COST: 7.979e-11	BEST COST: 6.911e-13
# EPOCH: 165	AVG COST: 9.883e-11	BEST COST: 6.911e-13
# EPOCH: 166	AVG COST: 1.261e-10	BEST COST: 6.911e-13
# EPOCH: 167	AVG COST: 8.825e-11	BEST COST: 6.911e-13
# EPOCH: 168	AVG COST: 1.521e-10	BEST COST: 6.911e-13
# EPOCH: 169	AVG COST: 2.722e-10	BEST COST: 6.911e-13
# EPOCH: 170	AVG COST: 8.247e-11	BEST COST: 6.911e-13
# EPOCH: 171	AVG COST: 2.008e-10	BEST COST: 6.911e-13
# EPOCH: 172	AVG COST: 1.393e-02	BEST COST: 6.911e-13
# EPOCH: 173	AVG COST: 8.051e-11	BEST COST: 6.911e-13
# EPOCH: 174	AVG COST: 1.126e-10	BEST COST: 6.911e-13
# EPOCH: 175	AVG COST: 1.672e-01	BEST COST: 6.911e-13
# EPOCH: 176	AVG COST: 9.225e-11	BEST COST: 6.911e-13
# EPOCH: 177	AVG COST: 1.164e-10	BEST COST: 6.911e-13
# EPOCH: 178	AVG COST: 1.069e-01	BEST COST: 6.911e-13
# EPOCH: 179	AVG COST: 1.459e-10	BEST COST: 6.911e-13
# EPOCH: 180	AVG COST: 1.069e-01	BEST COST: 6.911e-13
# EPOCH: 181	AVG COST: 1.182e-10	BEST COST: 6.911e-13
# EPOCH: 182	AVG COST: 4.425e-03	BEST COST: 6.911e-13
# EPOCH: 183	AVG COST: 1.080e-10	BEST COST: 6.911e-13
# EPOCH: 184	AVG COST: 8.997e-11	BEST COST: 6.911e-13
# EPOCH: 185	AVG COST: 2.726e-10	BEST COST: 6.911e-13
# EPOCH: 186	AVG COST: 8.793e-11	BEST COST: 6.911e-13
# EPOCH: 187	AVG COST: 2.135e-01	BEST COST: 6.911e-13
# EPOCH: 188	AVG COST: 1.497e-01	BEST COST: 6.911e-13
# EPOCH: 189	AVG COST: 1.405e-02	BEST COST: 6.911e-13
# EPOCH: 190	AVG COST: 8.637e-11	BEST COST: 6.911e-13
# EPOCH: 191	AVG COST: 7.345e-11	BEST COST: 6.911e-13
# EPOCH: 192	AVG COST: 9.069e-11	BEST COST: 6.911e-13
# EPOCH: 193	AVG COST: 5.742e-11	BEST COST: 6.911e-13
# EPOCH: 194	AVG COST: 9.447e-11	BEST COST: 6.911e-13
# EPOCH: 195	AVG COST: 4.607e-02	BEST COST: 6.911e-13
# EPOCH: 196	AVG COST: 2.439e-10	BEST COST: 6.911e-13
# EPOCH: 197	AVG COST: 8.150e-11	BEST COST: 6.911e-13
# EPOCH: 198	AVG COST: 1.093e-10	BEST COST: 6.911e-13
# EPOCH: 199	AVG COST: 7.535e-11	BEST COST: 6.911e-13
# EPOCH: 200	AVG COST: 5.955e-11	BEST COST: 6.911e-13
# EPOCH: 201	AVG COST: 1.187e-10	BEST COST: 6.911e-13
# EPOCH: 202	AVG COST: 1.482e-10	BEST COST: 6.911e-13
# EPOCH: 203	AVG COST: 1.378e-01	BEST COST: 6.911e-13
# EPOCH: 204	AVG COST: 1.341e-10	BEST COST: 6.911e-13
# EPOCH: 205	AVG COST: 1.014e-10	BEST COST: 6.911e-13
# EPOCH: 206	AVG COST: 7.400e-11	BEST COST: 6.911e-13
# EPOCH: 207	AVG COST: 1.011e-10	BEST COST: 6.911e-13
# EPOCH: 208	AVG COST: 1.624e-10	BEST COST: 6.911e-13
# EPOCH: 209	AVG COST: 1.672e-01	BEST COST: 6.911e-13
# EPOCH: 210	AVG COST: 8.070e-11	BEST COST: 6.911e-13
# EPOCH: 211	AVG COST: 1.188e-10	BEST COST: 6.911e-13
# EPOCH: 212	AVG COST: 5.169e-03	BEST COST: 6.911e-13
# EPOCH: 213	AVG COST: 9.289e-11	BEST COST: 6.911e-13
# EPOCH: 214	AVG COST: 7.984e-11	BEST COST: 6.911e-13
# EPOCH: 215	AVG COST: 1.461e-10	BEST COST: 6.911e-13
# EPOCH: 216	AVG COST: 6.447e-11	BEST COST: 6.911e-13
# EPOCH: 217	AVG COST: 9.138e-02	BEST COST: 6.911e-13
# EPOCH: 218	AVG COST: 8.996e-11	BEST COST: 6.911e-13
# EPOCH: 219	AVG COST: 1.193e-02	BEST COST: 6.911e-13
# EPOCH: 220	AVG COST: 1.365e-10	BEST COST: 6.911e-13
# EPOCH: 221	AVG COST: 5.696e-11	BEST COST: 6.911e-13
# EPOCH: 222	AVG COST: 1.052e-10	BEST COST: 6.911e-13
# EPOCH: 223	AVG COST: 6.858e-11	BEST COST: 6.911e-13
# EPOCH: 224	AVG COST: 1.760e-10	BEST COST: 6.911e-13
# EPOCH: 225	AVG COST: 1.247e-01	BEST COST: 6.911e-13
# EPOCH: 226	AVG COST: 6.603e-11	BEST COST: 6.911e-13
# EPOCH: 227	AVG COST: 1.395e-10	BEST COST: 6.911e-13
# EPOCH: 228	AVG COST: 1.004e-10	BEST COST: 6.911e-13
# EPOCH: 229	AVG COST: 7.082e-02	BEST COST: 6.911e-13
# EPOCH: 230	AVG COST: 1.160e-01	BEST COST: 6.911e-13
# EPOCH: 231	AVG COST: 7.829e-02	BEST COST: 6.911e-13
# EPOCH: 232	AVG COST: 7.571e-11	BEST COST: 6.911e-13
# EPOCH: 233	AVG COST: 1.534e-01	BEST COST: 6.911e-13
# EPOCH: 234	AVG COST: 1.985e-10	BEST COST: 6.911e-13
# EPOCH: 235	AVG COST: 5.682e-11	BEST COST: 6.911e-13
# EPOCH: 236	AVG COST: 1.672e-01	BEST COST: 6.911e-13
# EPOCH: 237	AVG COST: 8.054e-11	BEST COST: 6.911e-13
# EPOCH: 238	AVG COST: 6.747e-02	BEST COST: 6.911e-13
# EPOCH: 239	AVG COST: 3.598e-02	BEST COST: 6.911e-13
# EPOCH: 240	AVG COST: 1.769e-10	BEST COST: 6.911e-13
# EPOCH: 241	AVG COST: 1.672e-01	BEST COST: 6.911e-13
# EPOCH: 242	AVG COST: 1.059e-10	BEST COST: 6.911e-13
# EPOCH: 243	AVG COST: 2.248e-01	BEST COST: 6.911e-13
# EPOCH: 244	AVG COST: 1.672e-01	BEST COST: 6.911e-13
# EPOCH: 245	AVG COST: 1.527e-01	BEST COST: 6.911e-13
# EPOCH: 246	AVG COST: 1.075e-01	BEST COST: 6.911e-13
# EPOCH: 247	AVG COST: 7.949e-11	BEST COST: 6.911e-13
# EPOCH: 248	AVG COST: 1.672e-01	BEST COST: 6.911e-13
# EPOCH: 249	AVG COST: 1.672e-01	BEST COST: 6.911e-13
# OPTIMIZATION COMPLETE
# 	BEST COST LOCATION	EPOCH: 6	BLOCK: 30
# 	BEST COST: 6.911e-13

# %%
# calculate mean and median costs for each block
mean_costs = []
median_costs = []
for cost in history['cost']:
    mean_costs.append(np.mean(cost))
    median_costs.append(np.median(cost))

# plot median costs and print best point set, weights, and associated cost
plt.plot(np.arange(len(median_costs)), median_costs)
plt.xlabel('Epoch')
plt.ylabel('Epoch Median Cost')
plt.title('Median Cost per Epoch')
best = history['best']
print(history.keys())
print(best)
print(history['cost'][best[0]][best[1]])
print(history['point_sets'][best[0]][best[1]])
print(history['weight_sets'][best[0]][best[1]])
# Out:
# dict_keys(['cost', 'point_sets', 'weight_sets', 'temperature_history', 'best'])
# (6, 30)
# 6.91127315888106e-13
# [[4773], [9485], [798], [6067], [7611], [8718], [4887], [403], [8209], [4127], [1148], [9400]]
# [0.09734345 0.08805943 0.07627019 0.09102857 0.06793619 0.08028003
#  0.09703587 0.06802107 0.06559718 0.0982848  0.08254572 0.08759749]

# %% [markdown]
# Note that because this is a relatively simple example, we see an extremely low cost achieved very quickly and the median cost does not significantly decrease over time. For a more realistic example, see the atmospheric energy flux exmaple in <code>example.ipynb</code>.
